# %%
import pandas as pd
# 1. Read CSV file
df = pd.read_csv("House_analysis_data.csv")
# 2. Number of features (columns)
print("Number of Columns (Features):", df.shape[1])
# 3. Number of observations (rows)
print("Number of Rows (Observations):", df.shape[0])
# 4. Data type of each feature
print("\nData Types of Each Column:\n")
print(df.dtypes)
# 5. Missing values in each column
print("\nMissing Values in Each Column:\n")
print(df.isnull().sum())
# Out:
# Number of Columns (Features): 14
# Number of Rows (Observations): 400
#
# Data Types of Each Column:
#
# Title              object
# Locality           object
# Furnishing         object
# Built_up_area       int64
# Lease_type         object
# Available_from     object
# Price              object
# Bathrooms           int64
# Balcony           float64
# Carpet_area       float64
# Gas_Pipeline       object
# Gate_Community     object
# Floor_number      float64
# Total_floors      float64
# dtype: object
#
# Missing Values in Each Column:
#
# Title              0
# Locality           0
# Furnishing         0
# Built_up_area      0
# Lease_type         2
# Available_from     0
# Price              0
# Bathrooms          0
# Balcony           79
# Carpet_area       75
# Gas_Pipeline       0
# Gate_Community     0
# Floor_number      43
# Total_floors      43
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Title           400 non-null    object
#  1   Locality        400 non-null    object
#  2   Furnishing      400 non-null    object
#  3   Built_up_area   400 non-null    int64
#  4   Lease_type      398 non-null    object
#  5   Available_from  400 non-null    object
#  6   Price           400 non-null    object
#  7   Bathrooms       400 non-null    int64
#  8   Balcony         321 non-null    float64
#  9   Carpet_area     325 non-null    float64
#  10  Gas_Pipeline    400 non-null    object
#  11  Gate_Community  400 non-null    object
#  12  Floor_number    357 non-null    float64
#  13  Total_floors    357 non-null    float64
# dtypes: float64(4), int64(2), object(8)
# memory usage: 43.9+ KB

# %%
df.head()
# Out:
#                              Title                   Locality  \
# 0            2.5 BHK Flat for Rent   Tirumanahalli, Bangalore
# 1              1 BHK Flat for Rent      BTM Layout, Bangalore
# 2              2 BHK Flat for Rent    Mahadevapura, Bangalore
# 3              3 BHK Flat for Rent  Gunjur Village, Bangalore
# 4  1 RK Independent House for Rent    Mahadevapura, Bangalore
#
#         Furnishing  Built_up_area                   Lease_type Available_from  \
# 0   Semi Furnished           1265  Family / Bachelor / Company  Available now
# 1  Fully Furnished            700  Family / Bachelor / Company  Available now
# 2   Semi Furnished           1185  Family / Bachelor / Company      Nov, 2025
# 3   Semi Furnished           1655                       Family  Available now
# 4  Fully Furnished            400            Family / Bachelor  Available now
#
#     Price  Bathrooms  Balcony  Carpet_area Gas_Pipeline Gate_Community  \
# 0  42,006          2      1.0        795.0          Yes            Yes
# 1  28,500          1      NaN        600.0          Yes            Yes
# 2  38,000          2      1.0        850.0           No             No
# 3  65,000          3      3.0       1304.0           No            Yes
# 4  18,000          1      1.0          NaN           No             No
#
#    Floor_number  Total_floors
# 0           3.0          24.0
# 1           5.0           7.0
# 2           3.0           4.0
# 3          26.0          30.0
# 4           NaN           NaN

# %%
import pandas as pd
import numpy as np
import re

# Load CSV
df = pd.read_csv("House_analysis_data.csv")

# -------------------------------
# 1. REMOVE SPECIAL CHARACTERS
# -------------------------------

# Price – remove commas, spaces, currency symbols
df["Price"] = (
    df["Price"].astype(str)
    .str.replace(",", "")
    .str.replace(r"[^\d.]", "", regex=True)
)

# Built-up Area – extract numbers only
df["Built_up_area"] = (
    df["Built_up_area"]
    .astype(str)
    .str.extract(r"(\d+\.?\d*)")
)

# Carpet Area – extract only numeric part
df["Carpet_area"] = (
    df["Carpet_area"]
    .astype(str)
    .str.replace(",", "")
    .str.extract(r"(\d+\.?\d*)")
)

# Floor Number – extract floor number
df["Floor_number"] = (
    df["Floor_number"]
    .astype(str)
    .str.extract(r"(\d+)")
)

# Total Floors
df["Total_floors"] = (
    df["Total_floors"]
    .astype(str)
    .str.extract(r"(\d+)")
)


# # -------------------------------



# # -------------------------------
# # 6. DISPLAY CLEANED DATA
# # -------------------------------

# print("\nFinal Data Types:\n", df.dtypes)
# print("\nRemaining Missing Values:\n", df.isnull().sum())
# print("\nSample Cleaned Data:\n", df.head())

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Title           400 non-null    object
#  1   Locality        400 non-null    object
#  2   Furnishing      400 non-null    object
#  3   Built_up_area   400 non-null    object
#  4   Lease_type      398 non-null    object
#  5   Available_from  400 non-null    object
#  6   Price           400 non-null    object
#  7   Bathrooms       400 non-null    int64
#  8   Balcony         321 non-null    float64
#  9   Carpet_area     325 non-null    object
#  10  Gas_Pipeline    400 non-null    object
#  11  Gate_Community  400 non-null    object
#  12  Floor_number    357 non-null    object
#  13  Total_floors    357 non-null    object
# dtypes: float64(1), int64(1), object(12)
# memory usage: 43.9+ KB

# %%
df.head()
# Out:
#                              Title                   Locality  \
# 0            2.5 BHK Flat for Rent   Tirumanahalli, Bangalore
# 1              1 BHK Flat for Rent      BTM Layout, Bangalore
# 2              2 BHK Flat for Rent    Mahadevapura, Bangalore
# 3              3 BHK Flat for Rent  Gunjur Village, Bangalore
# 4  1 RK Independent House for Rent    Mahadevapura, Bangalore
#
#         Furnishing Built_up_area                   Lease_type Available_from  \
# 0   Semi Furnished          1265  Family / Bachelor / Company  Available now
# 1  Fully Furnished           700  Family / Bachelor / Company  Available now
# 2   Semi Furnished          1185  Family / Bachelor / Company      Nov, 2025
# 3   Semi Furnished          1655                       Family  Available now
# 4  Fully Furnished           400            Family / Bachelor  Available now
#
#    Price  Bathrooms  Balcony Carpet_area Gas_Pipeline Gate_Community  \
# 0  42006          2      1.0       795.0          Yes            Yes
# 1  28500          1      NaN       600.0          Yes            Yes
# 2  38000          2      1.0       850.0           No             No
# 3  65000          3      3.0      1304.0           No            Yes
# 4  18000          1      1.0         NaN           No             No
#
#   Floor_number Total_floors
# 0            3           24
# 1            5            7
# 2            3            4
# 3           26           30
# 4          NaN          NaN

# %%
print(df.dtypes)
# Out:
# Title              object
# Locality           object
# Furnishing         object
# Built_up_area      object
# Lease_type         object
# Available_from     object
# Price              object
# Bathrooms           int64
# Balcony           float64
# Carpet_area        object
# Gas_Pipeline       object
# Gate_Community     object
# Floor_number       object
# Total_floors       object
# dtype: object

# %%
# 2. FIX INCORRECT FORMATS / INVALID VALUES
# -------------------------------

# Replace empty strings or 'nan' with NaN
df.replace(["", " ", "nan", "None", None], np.nan, inplace=True)

# %%
df.head()
# Out:
#                              Title                   Locality  \
# 0            2.5 BHK Flat for Rent   Tirumanahalli, Bangalore
# 1              1 BHK Flat for Rent      BTM Layout, Bangalore
# 2              2 BHK Flat for Rent    Mahadevapura, Bangalore
# 3              3 BHK Flat for Rent  Gunjur Village, Bangalore
# 4  1 RK Independent House for Rent    Mahadevapura, Bangalore
#
#         Furnishing Built_up_area                   Lease_type Available_from  \
# 0   Semi Furnished          1265  Family / Bachelor / Company  Available now
# 1  Fully Furnished           700  Family / Bachelor / Company  Available now
# 2   Semi Furnished          1185  Family / Bachelor / Company      Nov, 2025
# 3   Semi Furnished          1655                       Family  Available now
# 4  Fully Furnished           400            Family / Bachelor  Available now
#
#    Price  Bathrooms  Balcony Carpet_area Gas_Pipeline Gate_Community  \
# 0  42006          2      1.0       795.0          Yes            Yes
# 1  28500          1      NaN       600.0          Yes            Yes
# 2  38000          2      1.0       850.0           No             No
# 3  65000          3      3.0      1304.0           No            Yes
# 4  18000          1      1.0         NaN           No             No
#
#   Floor_number Total_floors
# 0            3           24
# 1            5            7
# 2            3            4
# 3           26           30
# 4          NaN          NaN

# %%
# convert datatypes
numeric_cols = [
    "Price", "Built_up_area", "Carpet_area",
    "Bathrooms", "Balcony", "Floor_number", "Total_floors"
]

for col in numeric_cols:
    df[col] = pd.to_numeric(df[col], errors='coerce')
df.head()
# Out:
#                              Title                   Locality  \
# 0            2.5 BHK Flat for Rent   Tirumanahalli, Bangalore
# 1              1 BHK Flat for Rent      BTM Layout, Bangalore
# 2              2 BHK Flat for Rent    Mahadevapura, Bangalore
# 3              3 BHK Flat for Rent  Gunjur Village, Bangalore
# 4  1 RK Independent House for Rent    Mahadevapura, Bangalore
#
#         Furnishing  Built_up_area                   Lease_type Available_from  \
# 0   Semi Furnished           1265  Family / Bachelor / Company  Available now
# 1  Fully Furnished            700  Family / Bachelor / Company  Available now
# 2   Semi Furnished           1185  Family / Bachelor / Company      Nov, 2025
# 3   Semi Furnished           1655                       Family  Available now
# 4  Fully Furnished            400            Family / Bachelor  Available now
#
#    Price  Bathrooms  Balcony  Carpet_area Gas_Pipeline Gate_Community  \
# 0  42006          2      1.0        795.0          Yes            Yes
# 1  28500          1      NaN        600.0          Yes            Yes
# 2  38000          2      1.0        850.0           No             No
# 3  65000          3      3.0       1304.0           No            Yes
# 4  18000          1      1.0          NaN           No             No
#
#    Floor_number  Total_floors
# 0           3.0          24.0
# 1           5.0           7.0
# 2           3.0           4.0
# 3          26.0          30.0
# 4           NaN           NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Title           400 non-null    object
#  1   Locality        400 non-null    object
#  2   Furnishing      400 non-null    object
#  3   Built_up_area   400 non-null    int64
#  4   Lease_type      398 non-null    object
#  5   Available_from  400 non-null    object
#  6   Price           400 non-null    int64
#  7   Bathrooms       400 non-null    int64
#  8   Balcony         321 non-null    float64
#  9   Carpet_area     325 non-null    float64
#  10  Gas_Pipeline    400 non-null    object
#  11  Gate_Community  400 non-null    object
#  12  Floor_number    357 non-null    float64
#  13  Total_floors    357 non-null    float64
# dtypes: float64(4), int64(3), object(7)
# memory usage: 43.9+ KB

# %%
print(df.isnull().sum())
# Out:
# Title              0
# Locality           0
# Furnishing         0
# Built_up_area      0
# Lease_type         2
# Available_from     0
# Price              0
# Bathrooms          0
# Balcony           79
# Carpet_area       75
# Gas_Pipeline       0
# Gate_Community     0
# Floor_number      43
# Total_floors      43
# dtype: int64

# %%
# 4. HANDLE MISSING VALUES
# Numeric columns – fill missing with median
for col in numeric_cols:
    if df[col].isnull().sum() > 0:
        df[col] = df[col].fillna(df[col].median())
# Categorical – fill missing with mode
for col in ["Lease_type"]:
    if df[col].isnull().sum() > 0:
        df[col] = df[col].fillna(df[col].mode()[0])
df.head()
# Out:
#                              Title                   Locality  \
# 0            2.5 BHK Flat for Rent   Tirumanahalli, Bangalore
# 1              1 BHK Flat for Rent      BTM Layout, Bangalore
# 2              2 BHK Flat for Rent    Mahadevapura, Bangalore
# 3              3 BHK Flat for Rent  Gunjur Village, Bangalore
# 4  1 RK Independent House for Rent    Mahadevapura, Bangalore
#
#         Furnishing  Built_up_area                   Lease_type Available_from  \
# 0   Semi Furnished           1265  Family / Bachelor / Company  Available now
# 1  Fully Furnished            700  Family / Bachelor / Company  Available now
# 2   Semi Furnished           1185  Family / Bachelor / Company      Nov, 2025
# 3   Semi Furnished           1655                       Family  Available now
# 4  Fully Furnished            400            Family / Bachelor  Available now
#
#    Price  Bathrooms  Balcony  Carpet_area Gas_Pipeline Gate_Community  \
# 0  42006          2      1.0        795.0          Yes            Yes
# 1  28500          1      1.0        600.0          Yes            Yes
# 2  38000          2      1.0        850.0           No             No
# 3  65000          3      3.0       1304.0           No            Yes
# 4  18000          1      1.0        850.0           No             No
#
#    Floor_number  Total_floors
# 0           3.0          24.0
# 1           5.0           7.0
# 2           3.0           4.0
# 3          26.0          30.0
# 4           3.0           6.0

# %%
# 6. DISPLAY CLEANED DATA
# -------------------------------

print("\nFinal Data Types:\n", df.dtypes)
print("\nRemaining Missing Values:\n", df.isnull().sum())
print("\nSample Cleaned Data:\n", df.head())
# Out:
# Final Data Types:
#  Title              object
# Locality           object
# Furnishing         object
# Built_up_area       int64
# Lease_type         object
# Available_from     object
# Price               int64
# Bathrooms           int64
# Balcony           float64
# Carpet_area       float64
# Gas_Pipeline       object
# Gate_Community     object
# Floor_number      float64
# Total_floors      float64
# dtype: object
#
# Remaining Missing Values:
#  Title             0
# Locality          0
# Furnishing        0
# Built_up_area     0
# Lease_type        0
# Available_from    0
# Price             0
# Bathrooms         0
# Balcony           0
# Carpet_area       0
# Gas_Pipeline      0
# Gate_Community    0
# Floor_number      0
# Total_floors      0
# dtype: int64
#
# Sample Cleaned Data:
#                               Title                   Locality  \
# 0            2.5 BHK Flat for Rent   Tirumanahalli, Bangalore
# 1              1 BHK Flat for Rent      BTM Layout, Bangalore
# 2              2 BHK Flat for Rent    Mahadevapura, Bangalore
# 3              3 BHK Flat for Rent  Gunjur Village, Bangalore
# 4  1 RK Independent House for Rent    Mahadevapura, Bangalore
#
#         Furnishing  Built_up_area                   Lease_type Available_from  \
# 0   Semi Furnished           1265  Family / Bachelor / Company  Available now
# 1  Fully Furnished            700  Family / Bachelor / Company  Available now
# 2   Semi Furnished           1185  Family / Bachelor / Company      Nov, 2025
# 3   Semi Furnished           1655                       Family  Available now
# 4  Fully Furnished            400            Family / Bachelor  Available now
#
#    Price  Bathrooms  Balcony  Carpet_area Gas_Pipeline Gate_Community  \
# 0  42006          2      1.0        795.0          Yes            Yes
# 1  28500          1      1.0        600.0          Yes            Yes
# 2  38000          2      1.0        850.0           No             No
# 3  65000          3      3.0       1304.0           No            Yes
# 4  18000          1      1.0        850.0           No             No
#
#    Floor_number  Total_floors
# 0           3.0          24.0
# 1           5.0           7.0
# 2           3.0           4.0
# 3          26.0          30.0
# 4           3.0           6.0

# %%
df.head()
# Out:
#                              Title                   Locality  \
# 0            2.5 BHK Flat for Rent   Tirumanahalli, Bangalore
# 1              1 BHK Flat for Rent      BTM Layout, Bangalore
# 2              2 BHK Flat for Rent    Mahadevapura, Bangalore
# 3              3 BHK Flat for Rent  Gunjur Village, Bangalore
# 4  1 RK Independent House for Rent    Mahadevapura, Bangalore
#
#         Furnishing  Built_up_area                   Lease_type Available_from  \
# 0   Semi Furnished           1265  Family / Bachelor / Company  Available now
# 1  Fully Furnished            700  Family / Bachelor / Company  Available now
# 2   Semi Furnished           1185  Family / Bachelor / Company      Nov, 2025
# 3   Semi Furnished           1655                       Family  Available now
# 4  Fully Furnished            400            Family / Bachelor  Available now
#
#    Price  Bathrooms  Balcony  Carpet_area Gas_Pipeline Gate_Community  \
# 0  42006          2      1.0        795.0          Yes            Yes
# 1  28500          1      1.0        600.0          Yes            Yes
# 2  38000          2      1.0        850.0           No             No
# 3  65000          3      3.0       1304.0           No            Yes
# 4  18000          1      1.0        850.0           No             No
#
#    Floor_number  Total_floors
# 0           3.0          24.0
# 1           5.0           7.0
# 2           3.0           4.0
# 3          26.0          30.0
# 4           3.0           6.0

# %%
df.head()
# Out:
#                              Title                   Locality  \
# 0            2.5 BHK Flat for Rent   Tirumanahalli, Bangalore
# 1              1 BHK Flat for Rent      BTM Layout, Bangalore
# 2              2 BHK Flat for Rent    Mahadevapura, Bangalore
# 3              3 BHK Flat for Rent  Gunjur Village, Bangalore
# 4  1 RK Independent House for Rent    Mahadevapura, Bangalore
#
#         Furnishing  Built_up_area                   Lease_type Available_from  \
# 0   Semi Furnished           1265  Family / Bachelor / Company  Available now
# 1  Fully Furnished            700  Family / Bachelor / Company  Available now
# 2   Semi Furnished           1185  Family / Bachelor / Company      Nov, 2025
# 3   Semi Furnished           1655                       Family  Available now
# 4  Fully Furnished            400            Family / Bachelor  Available now
#
#    Price  Bathrooms  Balcony  Carpet_area Gas_Pipeline Gate_Community  \
# 0  42006          2      1.0        795.0          Yes            Yes
# 1  28500          1      1.0        600.0          Yes            Yes
# 2  38000          2      1.0        850.0           No             No
# 3  65000          3      3.0       1304.0           No            Yes
# 4  18000          1      1.0        850.0           No             No
#
#    Floor_number  Total_floors
# 0           3.0          24.0
# 1           5.0           7.0
# 2           3.0           4.0
# 3          26.0          30.0
# 4           3.0           6.0

# %%
df.Title
# Out:
# 0                 2.5 BHK Flat for Rent
# 1                   1 BHK Flat for Rent
# 2                   2 BHK Flat for Rent
# 3                   3 BHK Flat for Rent
# 4       1 RK Independent House for Rent
#                      ...
# 395                 1 BHK Flat for Rent
# 396                 1 BHK Flat for Rent
# 397                 1 BHK Flat for Rent
# 398                 4 BHK Flat for Rent
# 399    3 BHK Independent House for Rent
# Name: Title, Length: 400, dtype: object

# %%
df["BHK_Number"] = df["Title"].str.extract(r"(\d+\.?\d*)\s*BHK", expand=False)

# ---- Remove 'X BHK' and get property type ----
df["Property_Title"] = (
    df["Title"]
    .str.replace(r"\d+\.?\d*\s*BHK\s*", "", regex=True)   # remove "X BHK"
    .str.replace("for Rent", "", regex=False)             # remove "for Rent"
    .str.strip()
)

df.head()
# Out:
#                              Title                   Locality  \
# 0            2.5 BHK Flat for Rent   Tirumanahalli, Bangalore
# 1              1 BHK Flat for Rent      BTM Layout, Bangalore
# 2              2 BHK Flat for Rent    Mahadevapura, Bangalore
# 3              3 BHK Flat for Rent  Gunjur Village, Bangalore
# 4  1 RK Independent House for Rent    Mahadevapura, Bangalore
#
#         Furnishing  Built_up_area                   Lease_type Available_from  \
# 0   Semi Furnished           1265  Family / Bachelor / Company  Available now
# 1  Fully Furnished            700  Family / Bachelor / Company  Available now
# 2   Semi Furnished           1185  Family / Bachelor / Company      Nov, 2025
# 3   Semi Furnished           1655                       Family  Available now
# 4  Fully Furnished            400            Family / Bachelor  Available now
#
#    Price  Bathrooms  Balcony  Carpet_area Gas_Pipeline Gate_Community  \
# 0  42006          2      1.0        795.0          Yes            Yes
# 1  28500          1      1.0        600.0          Yes            Yes
# 2  38000          2      1.0        850.0           No             No
# 3  65000          3      3.0       1304.0           No            Yes
# 4  18000          1      1.0        850.0           No             No
#
#    Floor_number  Total_floors BHK_Number          Property_Title
# 0           3.0          24.0        2.5                    Flat
# 1           5.0           7.0          1                    Flat
# 2           3.0           4.0          2                    Flat
# 3          26.0          30.0          3                    Flat
# 4           3.0           6.0        NaN  1 RK Independent House

# %%
print(df.isnull().sum())
# Out:
# Title             0
# Locality          0
# Furnishing        0
# Built_up_area     0
# Lease_type        0
# Available_from    0
# Price             0
# Bathrooms         0
# Balcony           0
# Carpet_area       0
# Gas_Pipeline      0
# Gate_Community    0
# Floor_number      0
# Total_floors      0
# BHK_Number        6
# Property_Title    0
# dtype: int64

# %%
df[df["BHK_Number"].isnull()][["Title"]]
# Out:
#                                        Title
# 4            1 RK Independent House for Rent
# 22                      1 RK Studio for Rent
# 79                      1 RK Studio for Rent
# 126                       1 RK Flat for Rent
# 163                       1 RK Flat for Rent
# 364  1 RK Independent Builder Floor for Rent

# %%
df["BHK_Number"] = df["Title"].str.extract(r"(\d+\.?\d*)\s*(BHK|RK)", expand=False)[0]

# ---- Clean Property_Title (remove BHK/RK and 'for Rent') ----
df["Property_Title"] = (
    df["Title"]
    .str.replace(r"\d+\.?\d*\s*(BHK|RK)\s*", "", regex=True)   # remove 'X BHK' or 'X RK'
    .str.replace("for Rent", "", regex=False)                  # remove 'for Rent'
    .str.strip()
)

# %%
df
# Out:
#                                 Title                     Locality  \
# 0               2.5 BHK Flat for Rent     Tirumanahalli, Bangalore
# 1                 1 BHK Flat for Rent        BTM Layout, Bangalore
# 2                 2 BHK Flat for Rent      Mahadevapura, Bangalore
# 3                 3 BHK Flat for Rent    Gunjur Village, Bangalore
# 4     1 RK Independent House for Rent      Mahadevapura, Bangalore
# ..                                ...                          ...
# 395               1 BHK Flat for Rent  R.K. Hegde Nagar, Bangalore
# 396               1 BHK Flat for Rent        S.G. Palya, Bangalore
# 397               1 BHK Flat for Rent           Kannuru, Bangalore
# 398               4 BHK Flat for Rent            Jakkur, Bangalore
# 399  3 BHK Independent House for Rent      Mahadevapura, Bangalore
#
#           Furnishing  Built_up_area                   Lease_type  \
# 0     Semi Furnished           1265  Family / Bachelor / Company
# 1    Fully Furnished            700  Family / Bachelor / Company
# 2     Semi Furnished           1185  Family / Bachelor / Company
# 3     Semi Furnished           1655                       Family
# 4    Fully Furnished            400            Family / Bachelor
# ..               ...            ...                          ...
# 395   Semi Furnished            750  Family / Bachelor / Company
# 396  Fully Furnished            690            Family / Bachelor
# 397  Fully Furnished           1074  Family / Bachelor / Company
# 398   Semi Furnished           2020             Family / Company
# 399   Semi Furnished           1200            Family / Bachelor
#
#     Available_from   Price  Bathrooms  Balcony  Carpet_area Gas_Pipeline  \
# 0    Available now   42006          2      1.0        795.0          Yes
# 1    Available now   28500          1      1.0        600.0          Yes
# 2        Nov, 2025   38000          2      1.0        850.0           No
# 3    Available now   65000          3      3.0       1304.0           No
# 4    Available now   18000          1      1.0        850.0           No
# ..             ...     ...        ...      ...          ...          ...
# 395  Available now   18000          1      2.0        650.0          Yes
# 396  Available now   29000          1      1.0        600.0          Yes
# 397  Available now  150008          2      1.0        754.0          Yes
# 398  Available now   90000          4      1.0       1980.0           No
# 399      Dec, 2025   45500          2      1.0        850.0           No
#
#     Gate_Community  Floor_number  Total_floors BHK_Number     Property_Title
# 0              Yes           3.0          24.0        2.5               Flat
# 1              Yes           5.0           7.0          1               Flat
# 2               No           3.0           4.0          2               Flat
# 3              Yes          26.0          30.0          3               Flat
# 4               No           3.0           6.0          1  Independent House
# ..             ...           ...           ...        ...                ...
# 395            Yes           3.0           4.0          1               Flat
# 396            Yes           5.0           7.0          1               Flat
# 397            Yes           4.0          16.0          1               Flat
# 398            Yes           7.0          19.0          4               Flat
# 399             No           3.0           6.0          3  Independent House
#
# [400 rows x 16 columns]

# %%
df.Locality
# Out:
# 0         Tirumanahalli, Bangalore
# 1            BTM Layout, Bangalore
# 2          Mahadevapura, Bangalore
# 3        Gunjur Village, Bangalore
# 4          Mahadevapura, Bangalore
#                   ...
# 395    R.K. Hegde Nagar, Bangalore
# 396          S.G. Palya, Bangalore
# 397             Kannuru, Bangalore
# 398              Jakkur, Bangalore
# 399        Mahadevapura, Bangalore
# Name: Locality, Length: 400, dtype: object

# %%
df["Locality_area"] = df["Locality"].str.replace(", Bangalore", "", regex=False).str.strip()

# %%
df
# Out:
#                                 Title                     Locality  \
# 0               2.5 BHK Flat for Rent     Tirumanahalli, Bangalore
# 1                 1 BHK Flat for Rent        BTM Layout, Bangalore
# 2                 2 BHK Flat for Rent      Mahadevapura, Bangalore
# 3                 3 BHK Flat for Rent    Gunjur Village, Bangalore
# 4     1 RK Independent House for Rent      Mahadevapura, Bangalore
# ..                                ...                          ...
# 395               1 BHK Flat for Rent  R.K. Hegde Nagar, Bangalore
# 396               1 BHK Flat for Rent        S.G. Palya, Bangalore
# 397               1 BHK Flat for Rent           Kannuru, Bangalore
# 398               4 BHK Flat for Rent            Jakkur, Bangalore
# 399  3 BHK Independent House for Rent      Mahadevapura, Bangalore
#
#           Furnishing  Built_up_area                   Lease_type  \
# 0     Semi Furnished           1265  Family / Bachelor / Company
# 1    Fully Furnished            700  Family / Bachelor / Company
# 2     Semi Furnished           1185  Family / Bachelor / Company
# 3     Semi Furnished           1655                       Family
# 4    Fully Furnished            400            Family / Bachelor
# ..               ...            ...                          ...
# 395   Semi Furnished            750  Family / Bachelor / Company
# 396  Fully Furnished            690            Family / Bachelor
# 397  Fully Furnished           1074  Family / Bachelor / Company
# 398   Semi Furnished           2020             Family / Company
# 399   Semi Furnished           1200            Family / Bachelor
#
#     Available_from   Price  Bathrooms  Balcony  Carpet_area Gas_Pipeline  \
# 0    Available now   42006          2      1.0        795.0          Yes
# 1    Available now   28500          1      1.0        600.0          Yes
# 2        Nov, 2025   38000          2      1.0        850.0           No
# 3    Available now   65000          3      3.0       1304.0           No
# 4    Available now   18000          1      1.0        850.0           No
# ..             ...     ...        ...      ...          ...          ...
# 395  Available now   18000          1      2.0        650.0          Yes
# 396  Available now   29000          1      1.0        600.0          Yes
# 397  Available now  150008          2      1.0        754.0          Yes
# 398  Available now   90000          4      1.0       1980.0           No
# 399      Dec, 2025   45500          2      1.0        850.0           No
#
#     Gate_Community  Floor_number  Total_floors BHK_Number     Property_Title  \
# 0              Yes           3.0          24.0        2.5               Flat
# 1              Yes           5.0           7.0          1               Flat
# 2               No           3.0           4.0          2               Flat
# 3              Yes          26.0          30.0          3               Flat
# 4               No           3.0           6.0          1  Independent House
# ..             ...           ...           ...        ...                ...
# 395            Yes           3.0           4.0          1               Flat
# 396            Yes           5.0           7.0          1               Flat
# 397            Yes           4.0          16.0          1               Flat
# 398            Yes           7.0          19.0          4               Flat
# 399             No           3.0           6.0          3  Independent House
#
#         Locality_area
# 0       Tirumanahalli
# 1          BTM Layout
# 2        Mahadevapura
# 3      Gunjur Village
# 4        Mahadevapura
# ..                ...
# 395  R.K. Hegde Nagar
# 396        S.G. Palya
# 397           Kannuru
# 398            Jakkur
# 399      Mahadevapura
#
# [400 rows x 17 columns]

# %%
df.to_csv("House_analysis_data_is_cleaned.csv", index=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 17 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Title           400 non-null    object
#  1   Locality        400 non-null    object
#  2   Furnishing      400 non-null    object
#  3   Built_up_area   400 non-null    int64
#  4   Lease_type      400 non-null    object
#  5   Available_from  400 non-null    object
#  6   Price           400 non-null    int64
#  7   Bathrooms       400 non-null    int64
#  8   Balcony         400 non-null    float64
#  9   Carpet_area     400 non-null    float64
#  10  Gas_Pipeline    400 non-null    object
#  11  Gate_Community  400 non-null    object
#  12  Floor_number    400 non-null    float64
#  13  Total_floors    400 non-null    float64
#  14  BHK_Number      400 non-null    object
#  15  Property_Title  400 non-null    object
#  16  Locality_area   400 non-null    object
# dtypes: float64(4), int64(3), object(10)
# memory usage: 53.3+ KB

# %%
df["Property_Title"].astype("category")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 17 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Title           400 non-null    object
#  1   Locality        400 non-null    object
#  2   Furnishing      400 non-null    object
#  3   Built_up_area   400 non-null    int64
#  4   Lease_type      400 non-null    object
#  5   Available_from  400 non-null    object
#  6   Price           400 non-null    int64
#  7   Bathrooms       400 non-null    int64
#  8   Balcony         400 non-null    float64
#  9   Carpet_area     400 non-null    float64
#  10  Gas_Pipeline    400 non-null    object
#  11  Gate_Community  400 non-null    object
#  12  Floor_number    400 non-null    float64
#  13  Total_floors    400 non-null    float64
#  14  BHK_Number      400 non-null    object
#  15  Property_Title  400 non-null    object
#  16  Locality_area   400 non-null    object
# dtypes: float64(4), int64(3), object(10)
# memory usage: 53.3+ KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 17 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Title           400 non-null    object
#  1   Locality        400 non-null    object
#  2   Furnishing      400 non-null    object
#  3   Built_up_area   400 non-null    int64
#  4   Lease_type      400 non-null    object
#  5   Available_from  400 non-null    object
#  6   Price           400 non-null    int64
#  7   Bathrooms       400 non-null    int64
#  8   Balcony         400 non-null    float64
#  9   Carpet_area     400 non-null    float64
#  10  Gas_Pipeline    400 non-null    object
#  11  Gate_Community  400 non-null    object
#  12  Floor_number    400 non-null    float64
#  13  Total_floors    400 non-null    float64
#  14  BHK_Number      400 non-null    object
#  15  Property_Title  400 non-null    object
#  16  Locality_area   400 non-null    object
# dtypes: float64(4), int64(3), object(10)
# memory usage: 53.3+ KB

# %%
df.head(10)
# Out:
#                               Title                   Locality  \
# 0             2.5 BHK Flat for Rent   Tirumanahalli, Bangalore
# 1               1 BHK Flat for Rent      BTM Layout, Bangalore
# 2               2 BHK Flat for Rent    Mahadevapura, Bangalore
# 3               3 BHK Flat for Rent  Gunjur Village, Bangalore
# 4   1 RK Independent House for Rent    Mahadevapura, Bangalore
# 5             1 BHK Duplex for Rent     Brookefield, Bangalore
# 6               1 BHK Flat for Rent     Thanisandra, Bangalore
# 7          4 BHK Penthouse for Rent      Whitefield, Bangalore
# 8  4 BHK Independent House for Rent    Cheemasandra, Bangalore
# 9               3 BHK Flat for Rent    Narayanapura, Bangalore
#
#         Furnishing  Built_up_area                   Lease_type Available_from  \
# 0   Semi Furnished           1265  Family / Bachelor / Company  Available now
# 1  Fully Furnished            700  Family / Bachelor / Company  Available now
# 2   Semi Furnished           1185  Family / Bachelor / Company      Nov, 2025
# 3   Semi Furnished           1655                       Family  Available now
# 4  Fully Furnished            400            Family / Bachelor  Available now
# 5   Semi Furnished            700            Family / Bachelor  Available now
# 6   Semi Furnished            690  Family / Bachelor / Company  Available now
# 7   Semi Furnished           4400                       Family  Available now
# 8      Unfurnished           4000                       Family      Jan, 2026
# 9   Semi Furnished           1350  Family / Bachelor / Company  Available now
#
#     Price  Bathrooms  Balcony  Carpet_area Gas_Pipeline Gate_Community  \
# 0   42006          2      1.0        795.0          Yes            Yes
# 1   28500          1      1.0        600.0          Yes            Yes
# 2   38000          2      1.0        850.0           No             No
# 3   65000          3      3.0       1304.0           No            Yes
# 4   18000          1      1.0        850.0           No             No
# 5   32000          1      1.0        650.0           No             No
# 6   18000          1      1.0        600.0           No            Yes
# 7  160000          4      4.0       4000.0           No            Yes
# 8   90000          5      2.0       3900.0           No            Yes
# 9   50000          3      1.0        850.0           No             No
#
#    Floor_number  Total_floors BHK_Number     Property_Title   Locality_area
# 0           3.0          24.0        2.5               Flat   Tirumanahalli
# 1           5.0           7.0          1               Flat      BTM Layout
# 2           3.0           4.0          2               Flat    Mahadevapura
# 3          26.0          30.0          3               Flat  Gunjur Village
# 4           3.0           6.0          1  Independent House    Mahadevapura
# 5           1.0           6.0          1             Duplex     Brookefield
# 6           3.0           4.0          1               Flat     Thanisandra
# 7          18.0          18.0          4          Penthouse      Whitefield
# 8           1.0           4.0          4  Independent House    Cheemasandra
# 9           3.0           6.0          3               Flat    Narayanapura

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 17 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Title           400 non-null    object
#  1   Locality        400 non-null    object
#  2   Furnishing      400 non-null    category
#  3   Built_up_area   400 non-null    int64
#  4   Lease_type      400 non-null    object
#  5   Available_from  400 non-null    object
#  6   Price           400 non-null    int64
#  7   Bathrooms       400 non-null    int64
#  8   Balcony         400 non-null    float64
#  9   Carpet_area     400 non-null    float64
#  10  Gas_Pipeline    400 non-null    object
#  11  Gate_Community  400 non-null    object
#  12  Floor_number    400 non-null    float64
#  13  Total_floors    400 non-null    float64
#  14  BHK_Number      400 non-null    object
#  15  Property_Title  400 non-null    object
#  16  Locality_area   400 non-null    object
# dtypes: category(1), float64(4), int64(3), object(9)
# memory usage: 50.6+ KB

# %%
df["Furnishing"] = df["Furnishing"].astype("category")

# %%
df["Lease_type"] = df["Lease_type"].astype("category")
df["Gate_Community"] = df["Gate_Community"].map({"Yes": 1, "No": 0})
df["Gas_Pipeline"] = df["Gas_Pipeline"].map({"Yes": 1, "No": 0})
df["Available_from"] = df["Available_from"].replace(
    "Available now", pd.Timestamp.today().date()
)
df["Available_from"] = pd.to_datetime(df["Available_from"], errors="coerce")
df["Locality_area"] = df["Locality_area"].astype("category")

df["Property_Title"] = df["Property_Title"].astype("category")
# Convert BHK_Number from float to int
df["BHK_Number"] = df["BHK_Number"].astype("float")

# Verify the datatype
df["BHK_Number"].dtypes
# Out:
# dtype('float64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 17 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Title           400 non-null    object
#  1   Locality        400 non-null    object
#  2   Furnishing      400 non-null    category
#  3   Built_up_area   400 non-null    int64
#  4   Lease_type      400 non-null    category
#  5   Available_from  400 non-null    datetime64[ns]
#  6   Price           400 non-null    int64
#  7   Bathrooms       400 non-null    int64
#  8   Balcony         400 non-null    float64
#  9   Carpet_area     400 non-null    float64
#  10  Gas_Pipeline    0 non-null      float64
#  11  Gate_Community  0 non-null      float64
#  12  Floor_number    400 non-null    float64
#  13  Total_floors    400 non-null    float64
#  14  BHK_Number      400 non-null    float64
#  15  Property_Title  400 non-null    category
#  16  Locality_area   400 non-null    category
# dtypes: category(4), datetime64[ns](1), float64(7), int64(3), object(2)
# memory usage: 45.7+ KB

# %%
df
# Out:
#                                 Title                     Locality  \
# 0               2.5 BHK Flat for Rent     Tirumanahalli, Bangalore
# 1                 1 BHK Flat for Rent        BTM Layout, Bangalore
# 2                 2 BHK Flat for Rent      Mahadevapura, Bangalore
# 3                 3 BHK Flat for Rent    Gunjur Village, Bangalore
# 4     1 RK Independent House for Rent      Mahadevapura, Bangalore
# ..                                ...                          ...
# 395               1 BHK Flat for Rent  R.K. Hegde Nagar, Bangalore
# 396               1 BHK Flat for Rent        S.G. Palya, Bangalore
# 397               1 BHK Flat for Rent           Kannuru, Bangalore
# 398               4 BHK Flat for Rent            Jakkur, Bangalore
# 399  3 BHK Independent House for Rent      Mahadevapura, Bangalore
#
#           Furnishing  Built_up_area                   Lease_type  \
# 0     Semi Furnished           1265  Family / Bachelor / Company
# 1    Fully Furnished            700  Family / Bachelor / Company
# 2     Semi Furnished           1185  Family / Bachelor / Company
# 3     Semi Furnished           1655                       Family
# 4    Fully Furnished            400            Family / Bachelor
# ..               ...            ...                          ...
# 395   Semi Furnished            750  Family / Bachelor / Company
# 396  Fully Furnished            690            Family / Bachelor
# 397  Fully Furnished           1074  Family / Bachelor / Company
# 398   Semi Furnished           2020             Family / Company
# 399   Semi Furnished           1200            Family / Bachelor
#
#     Available_from   Price  Bathrooms  Balcony  Carpet_area  Gas_Pipeline  \
# 0       2025-11-24   42006          2      1.0        795.0           NaN
# 1       2025-11-24   28500          1      1.0        600.0           NaN
# 2       2025-11-01   38000          2      1.0        850.0           NaN
# 3       2025-11-24   65000          3      3.0       1304.0           NaN
# 4       2025-11-24   18000          1      1.0        850.0           NaN
# ..             ...     ...        ...      ...          ...           ...
# 395     2025-11-24   18000          1      2.0        650.0           NaN
# 396     2025-11-24   29000          1      1.0        600.0           NaN
# 397     2025-11-24  150008          2      1.0        754.0           NaN
# 398     2025-11-24   90000          4      1.0       1980.0           NaN
# 399     2025-12-01   45500          2      1.0        850.0           NaN
#
#      Gate_Community  Floor_number  Total_floors  BHK_Number  \
# 0               NaN           3.0          24.0         2.5
# 1               NaN           5.0           7.0         1.0
# 2               NaN           3.0           4.0         2.0
# 3               NaN          26.0          30.0         3.0
# 4               NaN           3.0           6.0         1.0
# ..              ...           ...           ...         ...
# 395             NaN           3.0           4.0         1.0
# 396             NaN           5.0           7.0         1.0
# 397             NaN           4.0          16.0         1.0
# 398             NaN           7.0          19.0         4.0
# 399             NaN           3.0           6.0         3.0
#
#         Property_Title     Locality_area
# 0                 Flat     Tirumanahalli
# 1                 Flat        BTM Layout
# 2                 Flat      Mahadevapura
# 3                 Flat    Gunjur Village
# 4    Independent House      Mahadevapura
# ..                 ...               ...
# 395               Flat  R.K. Hegde Nagar
# 396               Flat        S.G. Palya
# 397               Flat           Kannuru
# 398               Flat            Jakkur
# 399  Independent House      Mahadevapura
#
# [400 rows x 17 columns]
